# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 935us/sample - loss: 227.9686 - y1_output_loss: 108.1812 - y2_output_loss: 118.3293 - y1_output_root_mean_squared_error: 10.4403 - y2_output_root_mean_squared_error: 10.9073 - val_loss: 25.5758 - val_y1_output_loss: 11.9794 - val_y2_output_loss: 13.6806 - val_y1_output_root_mean_squared_error: 3.4820 - val_y2_output_root_mean_squared_error: 3.6676
# Epoch 2/500
# 614/614 [==============================] - 0s 151us/sample - loss: 28.9542 - y1_output_loss: 12.0341 - y2_output_loss: 16.7122 - y1_output_root_mean_squared_error: 3.4824 - y2_output_root_mean_squared_error: 4.1021 - val_loss: 18.0761 - val_y1_output_loss: 8.5929 - val_y2_output_loss: 9.3152 - val_y1_output_root_mean_squared_error: 2.9596 - val_y2_output_root_mean_squared_error: 3.0524
# Epoch 3/500
# 614/614 [==============================] - 0s 131us/sample - loss: 25.7520 - y1_output_loss: 9.7578 - y2_output_loss: 15.7594 - y1_output_root_mean_squared_error: 3.1374 - y2_output_root_mean_squared_error: 3.9886 - val_loss: 30.9766 - val_y1_output_loss: 10.1935 - val_y2_output_loss: 21.2810 - val_y1_output_root_mean_squared_error: 3.2002 - val_y2_output_root_mean_squared_error: 4.5536
# Epoch 4/500
# 614/614 [==============================] - 0s 131us/sample - loss: 26.3708 - y1_output_loss: 9.6389 - y2_output_loss: 16.5459 - y1_output_root_mean_squared_error: 3.1181 - y2_output_root_mean_squared_error: 4.0802 - val_loss: 23.8886 - val_y1_output_loss: 8.5876 - val_y2_output_loss: 14.8222 - val_y1_output_root_mean_squared_error: 2.9755 - val_y2_output_root_mean_squared_error: 3.8775
# Epoch 5/500
# 614/614 [==============================] - 0s 131us/sample - loss: 26.2643 - y1_output_loss: 10.0667 - y2_output_loss: 16.6556 - y1_output_root_mean_squared_error: 3.1403 - y2_output_root_mean_squared_error: 4.0500 - val_loss: 37.1983 - val_y1_output_loss: 16.5125 - val_y2_output_loss: 21.9848 - val_y1_output_root_mean_squared_error: 4.0171 - val_y2_output_root_mean_squared_error: 4.5892
# Epoch 6/500
# 614/614 [==============================] - 0s 131us/sample - loss: 25.5477 - y1_output_loss: 9.4636 - y2_output_loss: 15.9686 - y1_output_root_mean_squared_error: 3.0850 - y2_output_root_mean_squared_error: 4.0038 - val_loss: 18.8441 - val_y1_output_loss: 8.1481 - val_y2_output_loss: 10.2150 - val_y1_output_root_mean_squared_error: 2.9059 - val_y2_output_root_mean_squared_error: 3.2249
# Epoch 7/500
# 614/614 [==============================] - 0s 128us/sample - loss: 22.9059 - y1_output_loss: 9.0401 - y2_output_loss: 13.8767 - y1_output_root_mean_squared_error: 3.0085 - y2_output_root_mean_squared_error: 3.7222 - val_loss: 52.3558 - val_y1_output_loss: 12.2994 - val_y2_output_loss: 39.9576 - val_y1_output_root_mean_squared_error: 3.5440 - val_y2_output_root_mean_squared_error: 6.3084
# Epoch 8/500
# 614/614 [==============================] - 0s 130us/sample - loss: 33.8541 - y1_output_loss: 11.1831 - y2_output_loss: 22.5294 - y1_output_root_mean_squared_error: 3.3510 - y2_output_root_mean_squared_error: 4.7566 - val_loss: 19.0779 - val_y1_output_loss: 9.0177 - val_y2_output_loss: 9.9151 - val_y1_output_root_mean_squared_error: 3.0237 - val_y2_output_root_mean_squared_error: 3.1520
# Epoch 9/500
# 614/614 [==============================] - 0s 130us/sample - loss: 20.2069 - y1_output_loss: 7.9633 - y2_output_loss: 12.5750 - y1_output_root_mean_squared_error: 2.8143 - y2_output_root_mean_squared_error: 3.5053 - val_loss: 141.4702 - val_y1_output_loss: 28.3884 - val_y2_output_loss: 113.6017 - val_y1_output_root_mean_squared_error: 5.3495 - val_y2_output_root_mean_squared_error: 10.6232
# Epoch 10/500
# 614/614 [==============================] - 0s 129us/sample - loss: 26.8341 - y1_output_loss: 9.2693 - y2_output_loss: 17.5720 - y1_output_root_mean_squared_error: 3.0425 - y2_output_root_mean_squared_error: 4.1925 - val_loss: 16.7076 - val_y1_output_loss: 7.7464 - val_y2_output_loss: 8.6598 - val_y1_output_root_mean_squared_error: 2.8327 - val_y2_output_root_mean_squared_error: 2.9468
# Epoch 11/500
# 614/614 [==============================] - 0s 127us/sample - loss: 21.5673 - y1_output_loss: 8.0722 - y2_output_loss: 13.4688 - y1_output_root_mean_squared_error: 2.8449 - y2_output_root_mean_squared_error: 3.6707 - val_loss: 21.3240 - val_y1_output_loss: 8.9901 - val_y2_output_loss: 12.5408 - val_y1_output_root_mean_squared_error: 3.0175 - val_y2_output_root_mean_squared_error: 3.4955
# Epoch 12/500
# 614/614 [==============================] - 0s 127us/sample - loss: 19.9775 - y1_output_loss: 7.5536 - y2_output_loss: 12.4145 - y1_output_root_mean_squared_error: 2.7561 - y2_output_root_mean_squared_error: 3.5187 - val_loss: 50.6024 - val_y1_output_loss: 13.5942 - val_y2_output_loss: 36.9655 - val_y1_output_root_mean_squared_error: 3.7048 - val_y2_output_root_mean_squared_error: 6.0726
# Epoch 13/500
# 614/614 [==============================] - 0s 126us/sample - loss: 21.2057 - y1_output_loss: 7.7618 - y2_output_loss: 13.3963 - y1_output_root_mean_squared_error: 2.7873 - y2_output_root_mean_squared_error: 3.6656 - val_loss: 25.6543 - val_y1_output_loss: 9.8899 - val_y2_output_loss: 16.3137 - val_y1_output_root_mean_squared_error: 3.1505 - val_y2_output_root_mean_squared_error: 3.9660
# Epoch 14/500
# 614/614 [==============================] - 0s 132us/sample - loss: 17.3825 - y1_output_loss: 7.2142 - y2_output_loss: 10.0831 - y1_output_root_mean_squared_error: 2.6843 - y2_output_root_mean_squared_error: 3.1902 - val_loss: 17.9641 - val_y1_output_loss: 8.1609 - val_y2_output_loss: 9.2690 - val_y1_output_root_mean_squared_error: 2.9036 - val_y2_output_root_mean_squared_error: 3.0876
# Epoch 15/500
# 614/614 [==============================] - 0s 135us/sample - loss: 19.2966 - y1_output_loss: 7.3236 - y2_output_loss: 11.8137 - y1_output_root_mean_squared_error: 2.7168 - y2_output_root_mean_squared_error: 3.4519 - val_loss: 20.7401 - val_y1_output_loss: 8.1629 - val_y2_output_loss: 12.1612 - val_y1_output_root_mean_squared_error: 2.8866 - val_y2_output_root_mean_squared_error: 3.5224
# Epoch 16/500
# 614/614 [==============================] - 0s 134us/sample - loss: 17.4345 - y1_output_loss: 6.7274 - y2_output_loss: 10.5784 - y1_output_root_mean_squared_error: 2.6037 - y2_output_root_mean_squared_error: 3.2642 - val_loss: 14.1241 - val_y1_output_loss: 6.3125 - val_y2_output_loss: 7.6766 - val_y1_output_root_mean_squared_error: 2.5453 - val_y2_output_root_mean_squared_error: 2.7650
# Epoch 17/500
# 614/614 [==============================] - 0s 127us/sample - loss: 16.0186 - y1_output_loss: 6.3366 - y2_output_loss: 9.7936 - y1_output_root_mean_squared_error: 2.4953 - y2_output_root_mean_squared_error: 3.1292 - val_loss: 17.8397 - val_y1_output_loss: 7.8626 - val_y2_output_loss: 9.5464 - val_y1_output_root_mean_squared_error: 2.8435 - val_y2_output_root_mean_squared_error: 3.1232
# Epoch 18/500
# 614/614 [==============================] - 0s 128us/sample - loss: 17.4456 - y1_output_loss: 6.5302 - y2_output_loss: 10.9002 - y1_output_root_mean_squared_error: 2.5463 - y2_output_root_mean_squared_error: 3.3109 - val_loss: 13.6788 - val_y1_output_loss: 6.2951 - val_y2_output_loss: 7.1924 - val_y1_output_root_mean_squared_error: 2.5358 - val_y2_output_root_mean_squared_error: 2.6924
# Epoch 19/500
# 614/614 [==============================] - 0s 135us/sample - loss: 17.8468 - y1_output_loss: 6.6051 - y2_output_loss: 11.1431 - y1_output_root_mean_squared_error: 2.5695 - y2_output_root_mean_squared_error: 3.3533 - val_loss: 12.5282 - val_y1_output_loss: 5.7734 - val_y2_output_loss: 6.5697 - val_y1_output_root_mean_squared_error: 2.4281 - val_y2_output_root_mean_squared_error: 2.5754
# Epoch 20/500
# 614/614 [==============================] - 0s 137us/sample - loss: 17.0743 - y1_output_loss: 6.4404 - y2_output_loss: 10.7997 - y1_output_root_mean_squared_error: 2.5199 - y2_output_root_mean_squared_error: 3.2749 - val_loss: 49.6266 - val_y1_output_loss: 17.6884 - val_y2_output_loss: 34.2782 - val_y1_output_root_mean_squared_error: 4.1303 - val_y2_output_root_mean_squared_error: 5.7068
# Epoch 21/500
# 614/614 [==============================] - 0s 134us/sample - loss: 16.4418 - y1_output_loss: 6.0484 - y2_output_loss: 10.3939 - y1_output_root_mean_squared_error: 2.4537 - y2_output_root_mean_squared_error: 3.2282 - val_loss: 12.7180 - val_y1_output_loss: 5.9363 - val_y2_output_loss: 6.5973 - val_y1_output_root_mean_squared_error: 2.4640 - val_y2_output_root_mean_squared_error: 2.5781
# Epoch 22/500
# 614/614 [==============================] - 0s 132us/sample - loss: 15.4248 - y1_output_loss: 5.5170 - y2_output_loss: 9.9434 - y1_output_root_mean_squared_error: 2.3521 - y2_output_root_mean_squared_error: 3.1452 - val_loss: 18.7079 - val_y1_output_loss: 5.7719 - val_y2_output_loss: 13.4981 - val_y1_output_root_mean_squared_error: 2.4034 - val_y2_output_root_mean_squared_error: 3.5960
# Epoch 23/500
# 614/614 [==============================] - 0s 128us/sample - loss: 15.3609 - y1_output_loss: 5.4718 - y2_output_loss: 10.1854 - y1_output_root_mean_squared_error: 2.3324 - y2_output_root_mean_squared_error: 3.1497 - val_loss: 60.6395 - val_y1_output_loss: 11.4307 - val_y2_output_loss: 48.9745 - val_y1_output_root_mean_squared_error: 3.4008 - val_y2_output_root_mean_squared_error: 7.0053
# Epoch 24/500
# 614/614 [==============================] - 0s 127us/sample - loss: 13.9958 - y1_output_loss: 5.0974 - y2_output_loss: 8.7721 - y1_output_root_mean_squared_error: 2.2684 - y2_output_root_mean_squared_error: 2.9749 - val_loss: 10.7575 - val_y1_output_loss: 4.9809 - val_y2_output_loss: 5.5516 - val_y1_output_root_mean_squared_error: 2.2547 - val_y2_output_root_mean_squared_error: 2.3820
# Epoch 25/500
# 614/614 [==============================] - 0s 128us/sample - loss: 12.9428 - y1_output_loss: 4.6209 - y2_output_loss: 8.3504 - y1_output_root_mean_squared_error: 2.1522 - y2_output_root_mean_squared_error: 2.8829 - val_loss: 22.4993 - val_y1_output_loss: 8.0868 - val_y2_output_loss: 14.0434 - val_y1_output_root_mean_squared_error: 2.8665 - val_y2_output_root_mean_squared_error: 3.7792
# Epoch 26/500
# 614/614 [==============================] - 0s 131us/sample - loss: 13.3299 - y1_output_loss: 4.7841 - y2_output_loss: 8.5351 - y1_output_root_mean_squared_error: 2.1947 - y2_output_root_mean_squared_error: 2.9177 - val_loss: 27.5751 - val_y1_output_loss: 8.9402 - val_y2_output_loss: 18.1794 - val_y1_output_root_mean_squared_error: 3.0201 - val_y2_output_root_mean_squared_error: 4.2958
# Epoch 27/500
# 614/614 [==============================] - 0s 132us/sample - loss: 13.7437 - y1_output_loss: 4.4351 - y2_output_loss: 9.2382 - y1_output_root_mean_squared_error: 2.1144 - y2_output_root_mean_squared_error: 3.0451 - val_loss: 10.6684 - val_y1_output_loss: 4.6611 - val_y2_output_loss: 6.1823 - val_y1_output_root_mean_squared_error: 2.1613 - val_y2_output_root_mean_squared_error: 2.4489
# Epoch 28/500
# 614/614 [==============================] - 0s 129us/sample - loss: 11.2486 - y1_output_loss: 4.2637 - y2_output_loss: 7.2795 - y1_output_root_mean_squared_error: 2.0166 - y2_output_root_mean_squared_error: 2.6799 - val_loss: 38.8984 - val_y1_output_loss: 9.3348 - val_y2_output_loss: 31.2097 - val_y1_output_root_mean_squared_error: 3.0169 - val_y2_output_root_mean_squared_error: 5.4586
# Epoch 29/500
# 614/614 [==============================] - 0s 136us/sample - loss: 13.9779 - y1_output_loss: 4.4556 - y2_output_loss: 9.5525 - y1_output_root_mean_squared_error: 2.1053 - y2_output_root_mean_squared_error: 3.0896 - val_loss: 21.1091 - val_y1_output_loss: 9.1245 - val_y2_output_loss: 11.8810 - val_y1_output_root_mean_squared_error: 3.0200 - val_y2_output_root_mean_squared_error: 3.4625
# Epoch 30/500
# 614/614 [==============================] - 0s 132us/sample - loss: 11.1825 - y1_output_loss: 3.9300 - y2_output_loss: 7.1853 - y1_output_root_mean_squared_error: 1.9903 - y2_output_root_mean_squared_error: 2.6873 - val_loss: 16.7324 - val_y1_output_loss: 6.1789 - val_y2_output_loss: 10.1366 - val_y1_output_root_mean_squared_error: 2.5158 - val_y2_output_root_mean_squared_error: 3.2254
# Epoch 31/500
# 614/614 [==============================] - 0s 132us/sample - loss: 10.2619 - y1_output_loss: 3.6730 - y2_output_loss: 6.6401 - y1_output_root_mean_squared_error: 1.9110 - y2_output_root_mean_squared_error: 2.5710 - val_loss: 10.7399 - val_y1_output_loss: 4.7137 - val_y2_output_loss: 6.3350 - val_y1_output_root_mean_squared_error: 2.1618 - val_y2_output_root_mean_squared_error: 2.4631
# Epoch 32/500
# 614/614 [==============================] - 0s 126us/sample - loss: 11.0284 - y1_output_loss: 3.8513 - y2_output_loss: 7.3199 - y1_output_root_mean_squared_error: 1.9484 - y2_output_root_mean_squared_error: 2.6893 - val_loss: 9.5395 - val_y1_output_loss: 4.6356 - val_y2_output_loss: 5.1724 - val_y1_output_root_mean_squared_error: 2.1379 - val_y2_output_root_mean_squared_error: 2.2291
# Epoch 33/500
# 614/614 [==============================] - 0s 137us/sample - loss: 10.8206 - y1_output_loss: 3.6859 - y2_output_loss: 7.0528 - y1_output_root_mean_squared_error: 1.9279 - y2_output_root_mean_squared_error: 2.6653 - val_loss: 9.0897 - val_y1_output_loss: 3.9407 - val_y2_output_loss: 5.3403 - val_y1_output_root_mean_squared_error: 1.9850 - val_y2_output_root_mean_squared_error: 2.2692
# Epoch 34/500
# 614/614 [==============================] - 0s 133us/sample - loss: 9.8279 - y1_output_loss: 3.4619 - y2_output_loss: 6.2838 - y1_output_root_mean_squared_error: 1.8665 - y2_output_root_mean_squared_error: 2.5187 - val_loss: 8.4311 - val_y1_output_loss: 3.5985 - val_y2_output_loss: 4.7920 - val_y1_output_root_mean_squared_error: 1.9147 - val_y2_output_root_mean_squared_error: 2.1829
# Epoch 35/500
# 614/614 [==============================] - 0s 132us/sample - loss: 8.6878 - y1_output_loss: 3.0842 - y2_output_loss: 5.6235 - y1_output_root_mean_squared_error: 1.7497 - y2_output_root_mean_squared_error: 2.3720 - val_loss: 9.7062 - val_y1_output_loss: 3.7542 - val_y2_output_loss: 5.7159 - val_y1_output_root_mean_squared_error: 1.9617 - val_y2_output_root_mean_squared_error: 2.4203
# Epoch 36/500
# 614/614 [==============================] - 0s 137us/sample - loss: 10.3972 - y1_output_loss: 3.5479 - y2_output_loss: 6.7864 - y1_output_root_mean_squared_error: 1.8914 - y2_output_root_mean_squared_error: 2.6115 - val_loss: 15.0078 - val_y1_output_loss: 5.0620 - val_y2_output_loss: 9.8247 - val_y1_output_root_mean_squared_error: 2.2539 - val_y2_output_root_mean_squared_error: 3.1508
# Epoch 37/500
# 614/614 [==============================] - 0s 133us/sample - loss: 10.9656 - y1_output_loss: 3.4388 - y2_output_loss: 7.5051 - y1_output_root_mean_squared_error: 1.8438 - y2_output_root_mean_squared_error: 2.7506 - val_loss: 14.8829 - val_y1_output_loss: 7.3152 - val_y2_output_loss: 8.4993 - val_y1_output_root_mean_squared_error: 2.6430 - val_y2_output_root_mean_squared_error: 2.8102
# Epoch 38/500
# 614/614 [==============================] - 0s 138us/sample - loss: 8.9126 - y1_output_loss: 3.0020 - y2_output_loss: 5.9413 - y1_output_root_mean_squared_error: 1.7210 - y2_output_root_mean_squared_error: 2.4394 - val_loss: 9.6822 - val_y1_output_loss: 3.8123 - val_y2_output_loss: 5.6024 - val_y1_output_root_mean_squared_error: 1.9857 - val_y2_output_root_mean_squared_error: 2.3957
# Epoch 39/500
# 614/614 [==============================] - 0s 134us/sample - loss: 9.6493 - y1_output_loss: 3.1993 - y2_output_loss: 6.4299 - y1_output_root_mean_squared_error: 1.7897 - y2_output_root_mean_squared_error: 2.5390 - val_loss: 15.2209 - val_y1_output_loss: 4.3638 - val_y2_output_loss: 10.6770 - val_y1_output_root_mean_squared_error: 2.0992 - val_y2_output_root_mean_squared_error: 3.2885
# Epoch 40/500
# 614/614 [==============================] - 0s 134us/sample - loss: 10.6973 - y1_output_loss: 3.2404 - y2_output_loss: 7.5127 - y1_output_root_mean_squared_error: 1.7810 - y2_output_root_mean_squared_error: 2.7433 - val_loss: 9.0162 - val_y1_output_loss: 3.4737 - val_y2_output_loss: 5.9156 - val_y1_output_root_mean_squared_error: 1.8537 - val_y2_output_root_mean_squared_error: 2.3622
# Epoch 41/500
# 614/614 [==============================] - 0s 133us/sample - loss: 9.0099 - y1_output_loss: 2.8171 - y2_output_loss: 6.1447 - y1_output_root_mean_squared_error: 1.6847 - y2_output_root_mean_squared_error: 2.4843 - val_loss: 7.8739 - val_y1_output_loss: 3.3765 - val_y2_output_loss: 4.5583 - val_y1_output_root_mean_squared_error: 1.8371 - val_y2_output_root_mean_squared_error: 2.1211
# Epoch 42/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.5554 - y1_output_loss: 2.4665 - y2_output_loss: 5.0842 - y1_output_root_mean_squared_error: 1.5747 - y2_output_root_mean_squared_error: 2.2529 - val_loss: 7.4363 - val_y1_output_loss: 3.2438 - val_y2_output_loss: 4.4681 - val_y1_output_root_mean_squared_error: 1.7925 - val_y2_output_root_mean_squared_error: 2.0550
# Epoch 43/500
# 614/614 [==============================] - 0s 129us/sample - loss: 10.0050 - y1_output_loss: 3.2104 - y2_output_loss: 6.8433 - y1_output_root_mean_squared_error: 1.7927 - y2_output_root_mean_squared_error: 2.6060 - val_loss: 14.2510 - val_y1_output_loss: 5.7213 - val_y2_output_loss: 9.1702 - val_y1_output_root_mean_squared_error: 2.3519 - val_y2_output_root_mean_squared_error: 2.9529
# Epoch 44/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.0120 - y1_output_loss: 2.7298 - y2_output_loss: 6.2976 - y1_output_root_mean_squared_error: 1.6502 - y2_output_root_mean_squared_error: 2.5078 - val_loss: 25.5040 - val_y1_output_loss: 5.9956 - val_y2_output_loss: 19.2822 - val_y1_output_root_mean_squared_error: 2.4602 - val_y2_output_root_mean_squared_error: 4.4104
# Epoch 45/500
# 614/614 [==============================] - 0s 130us/sample - loss: 9.2851 - y1_output_loss: 2.9060 - y2_output_loss: 6.3019 - y1_output_root_mean_squared_error: 1.7122 - y2_output_root_mean_squared_error: 2.5206 - val_loss: 5.9345 - val_y1_output_loss: 2.3426 - val_y2_output_loss: 3.8610 - val_y1_output_root_mean_squared_error: 1.5176 - val_y2_output_root_mean_squared_error: 1.9056
# Epoch 46/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.2239 - y1_output_loss: 2.6248 - y2_output_loss: 5.5871 - y1_output_root_mean_squared_error: 1.6257 - y2_output_root_mean_squared_error: 2.3624 - val_loss: 10.3219 - val_y1_output_loss: 2.9472 - val_y2_output_loss: 7.1745 - val_y1_output_root_mean_squared_error: 1.7413 - val_y2_output_root_mean_squared_error: 2.7000
# Epoch 47/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.7025 - y1_output_loss: 2.4956 - y2_output_loss: 5.3909 - y1_output_root_mean_squared_error: 1.5790 - y2_output_root_mean_squared_error: 2.2824 - val_loss: 31.8090 - val_y1_output_loss: 6.3944 - val_y2_output_loss: 25.1551 - val_y1_output_root_mean_squared_error: 2.5511 - val_y2_output_root_mean_squared_error: 5.0300
# Epoch 48/500
# 614/614 [==============================] - 0s 129us/sample - loss: 8.0828 - y1_output_loss: 2.5819 - y2_output_loss: 5.5766 - y1_output_root_mean_squared_error: 1.5976 - y2_output_root_mean_squared_error: 2.3517 - val_loss: 6.8361 - val_y1_output_loss: 3.1563 - val_y2_output_loss: 3.9658 - val_y1_output_root_mean_squared_error: 1.7534 - val_y2_output_root_mean_squared_error: 1.9395
# Epoch 49/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.3646 - y1_output_loss: 2.3056 - y2_output_loss: 5.0037 - y1_output_root_mean_squared_error: 1.5244 - y2_output_root_mean_squared_error: 2.2452 - val_loss: 5.7856 - val_y1_output_loss: 2.1571 - val_y2_output_loss: 3.6195 - val_y1_output_root_mean_squared_error: 1.4761 - val_y2_output_root_mean_squared_error: 1.8991
# Epoch 50/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.8355 - y1_output_loss: 2.4203 - y2_output_loss: 5.5619 - y1_output_root_mean_squared_error: 1.5425 - y2_output_root_mean_squared_error: 2.3358 - val_loss: 23.1740 - val_y1_output_loss: 9.3960 - val_y2_output_loss: 14.4886 - val_y1_output_root_mean_squared_error: 3.0106 - val_y2_output_root_mean_squared_error: 3.7564
# Epoch 51/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.5553 - y1_output_loss: 2.3725 - y2_output_loss: 5.1271 - y1_output_root_mean_squared_error: 1.5455 - y2_output_root_mean_squared_error: 2.2731 - val_loss: 5.5833 - val_y1_output_loss: 1.9867 - val_y2_output_loss: 3.6502 - val_y1_output_root_mean_squared_error: 1.4051 - val_y2_output_root_mean_squared_error: 1.8998
# Epoch 52/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.1263 - y1_output_loss: 2.2281 - y2_output_loss: 4.8729 - y1_output_root_mean_squared_error: 1.4990 - y2_output_root_mean_squared_error: 2.2089 - val_loss: 13.7598 - val_y1_output_loss: 3.3778 - val_y2_output_loss: 10.0867 - val_y1_output_root_mean_squared_error: 1.8664 - val_y2_output_root_mean_squared_error: 3.2057
# Epoch 53/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.3820 - y1_output_loss: 2.1418 - y2_output_loss: 4.2566 - y1_output_root_mean_squared_error: 1.4508 - y2_output_root_mean_squared_error: 2.0681 - val_loss: 4.9195 - val_y1_output_loss: 1.7958 - val_y2_output_loss: 3.2507 - val_y1_output_root_mean_squared_error: 1.3399 - val_y2_output_root_mean_squared_error: 1.7675
# Epoch 54/500
# 614/614 [==============================] - 0s 130us/sample - loss: 7.8159 - y1_output_loss: 2.3643 - y2_output_loss: 5.4444 - y1_output_root_mean_squared_error: 1.5404 - y2_output_root_mean_squared_error: 2.3330 - val_loss: 5.5762 - val_y1_output_loss: 1.8478 - val_y2_output_loss: 3.6753 - val_y1_output_root_mean_squared_error: 1.3730 - val_y2_output_root_mean_squared_error: 1.9212
# Epoch 55/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.4375 - y1_output_loss: 1.8616 - y2_output_loss: 3.7412 - y1_output_root_mean_squared_error: 1.3380 - y2_output_root_mean_squared_error: 1.9098 - val_loss: 24.0240 - val_y1_output_loss: 8.1498 - val_y2_output_loss: 17.4281 - val_y1_output_root_mean_squared_error: 2.7842 - val_y2_output_root_mean_squared_error: 4.0339
# Epoch 56/500
# 614/614 [==============================] - 0s 130us/sample - loss: 7.8235 - y1_output_loss: 2.3266 - y2_output_loss: 5.8960 - y1_output_root_mean_squared_error: 1.4778 - y2_output_root_mean_squared_error: 2.3748 - val_loss: 55.9324 - val_y1_output_loss: 20.1103 - val_y2_output_loss: 38.9323 - val_y1_output_root_mean_squared_error: 4.3750 - val_y2_output_root_mean_squared_error: 6.0656
# Epoch 57/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.8514 - y1_output_loss: 2.0446 - y2_output_loss: 4.7874 - y1_output_root_mean_squared_error: 1.4325 - y2_output_root_mean_squared_error: 2.1907 - val_loss: 5.8970 - val_y1_output_loss: 1.8430 - val_y2_output_loss: 4.1194 - val_y1_output_root_mean_squared_error: 1.3772 - val_y2_output_root_mean_squared_error: 2.0001
# Epoch 58/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.6053 - y1_output_loss: 2.0878 - y2_output_loss: 4.5098 - y1_output_root_mean_squared_error: 1.4490 - y2_output_root_mean_squared_error: 2.1227 - val_loss: 13.3598 - val_y1_output_loss: 2.4915 - val_y2_output_loss: 10.6348 - val_y1_output_root_mean_squared_error: 1.6036 - val_y2_output_root_mean_squared_error: 3.2845
# Epoch 59/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.7799 - y1_output_loss: 2.5214 - y2_output_loss: 6.2255 - y1_output_root_mean_squared_error: 1.5942 - y2_output_root_mean_squared_error: 2.4977 - val_loss: 12.5089 - val_y1_output_loss: 3.1776 - val_y2_output_loss: 9.1722 - val_y1_output_root_mean_squared_error: 1.8010 - val_y2_output_root_mean_squared_error: 3.0439
# Epoch 60/500
# 614/614 [==============================] - 0s 133us/sample - loss: 10.2187 - y1_output_loss: 2.9126 - y2_output_loss: 7.2114 - y1_output_root_mean_squared_error: 1.7141 - y2_output_root_mean_squared_error: 2.6982 - val_loss: 4.9455 - val_y1_output_loss: 1.6637 - val_y2_output_loss: 3.2981 - val_y1_output_root_mean_squared_error: 1.2992 - val_y2_output_root_mean_squared_error: 1.8049
# Epoch 61/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.2679 - y1_output_loss: 1.8756 - y2_output_loss: 4.4176 - y1_output_root_mean_squared_error: 1.3559 - y2_output_root_mean_squared_error: 2.1046 - val_loss: 4.7230 - val_y1_output_loss: 1.6640 - val_y2_output_loss: 3.0387 - val_y1_output_root_mean_squared_error: 1.3059 - val_y2_output_root_mean_squared_error: 1.7371
# Epoch 62/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.6303 - y1_output_loss: 1.5410 - y2_output_loss: 4.0444 - y1_output_root_mean_squared_error: 1.2440 - y2_output_root_mean_squared_error: 2.0206 - val_loss: 6.0492 - val_y1_output_loss: 1.8275 - val_y2_output_loss: 4.0813 - val_y1_output_root_mean_squared_error: 1.3759 - val_y2_output_root_mean_squared_error: 2.0386
# Epoch 63/500
# 614/614 [==============================] - 0s 138us/sample - loss: 6.3251 - y1_output_loss: 1.7625 - y2_output_loss: 4.6696 - y1_output_root_mean_squared_error: 1.3254 - y2_output_root_mean_squared_error: 2.1374 - val_loss: 36.0366 - val_y1_output_loss: 6.9658 - val_y2_output_loss: 29.4322 - val_y1_output_root_mean_squared_error: 2.6225 - val_y2_output_root_mean_squared_error: 5.3999
# Epoch 64/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.1110 - y1_output_loss: 1.4704 - y2_output_loss: 4.6180 - y1_output_root_mean_squared_error: 1.2107 - y2_output_root_mean_squared_error: 2.1553 - val_loss: 5.0093 - val_y1_output_loss: 1.7324 - val_y2_output_loss: 3.4309 - val_y1_output_root_mean_squared_error: 1.3179 - val_y2_output_root_mean_squared_error: 1.8090
# Epoch 65/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.2810 - y1_output_loss: 1.3980 - y2_output_loss: 3.9212 - y1_output_root_mean_squared_error: 1.1819 - y2_output_root_mean_squared_error: 1.9708 - val_loss: 5.9518 - val_y1_output_loss: 1.5212 - val_y2_output_loss: 4.3074 - val_y1_output_root_mean_squared_error: 1.2546 - val_y2_output_root_mean_squared_error: 2.0923
# Epoch 66/500
# 614/614 [==============================] - 0s 137us/sample - loss: 7.0041 - y1_output_loss: 1.8891 - y2_output_loss: 5.1326 - y1_output_root_mean_squared_error: 1.3752 - y2_output_root_mean_squared_error: 2.2612 - val_loss: 8.3757 - val_y1_output_loss: 3.5745 - val_y2_output_loss: 5.1282 - val_y1_output_root_mean_squared_error: 1.8624 - val_y2_output_root_mean_squared_error: 2.2152
# Epoch 67/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.4475 - y1_output_loss: 1.4644 - y2_output_loss: 4.0068 - y1_output_root_mean_squared_error: 1.2148 - y2_output_root_mean_squared_error: 1.9929 - val_loss: 4.1063 - val_y1_output_loss: 1.1944 - val_y2_output_loss: 2.8567 - val_y1_output_root_mean_squared_error: 1.1010 - val_y2_output_root_mean_squared_error: 1.7012
# Epoch 68/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.7326 - y1_output_loss: 1.2625 - y2_output_loss: 3.4758 - y1_output_root_mean_squared_error: 1.1190 - y2_output_root_mean_squared_error: 1.8656 - val_loss: 4.8638 - val_y1_output_loss: 1.4017 - val_y2_output_loss: 3.6232 - val_y1_output_root_mean_squared_error: 1.1967 - val_y2_output_root_mean_squared_error: 1.8525
# Epoch 69/500
# 614/614 [==============================] - 0s 145us/sample - loss: 4.9747 - y1_output_loss: 1.2431 - y2_output_loss: 3.7094 - y1_output_root_mean_squared_error: 1.1122 - y2_output_root_mean_squared_error: 1.9333 - val_loss: 6.0302 - val_y1_output_loss: 1.7340 - val_y2_output_loss: 4.5627 - val_y1_output_root_mean_squared_error: 1.3072 - val_y2_output_root_mean_squared_error: 2.0788
# Epoch 70/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.5301 - y1_output_loss: 1.0755 - y2_output_loss: 3.4432 - y1_output_root_mean_squared_error: 1.0418 - y2_output_root_mean_squared_error: 1.8560 - val_loss: 4.4331 - val_y1_output_loss: 1.4061 - val_y2_output_loss: 2.9942 - val_y1_output_root_mean_squared_error: 1.1815 - val_y2_output_root_mean_squared_error: 1.7428
# Epoch 71/500
# 614/614 [==============================] - 0s 145us/sample - loss: 4.4546 - y1_output_loss: 1.1613 - y2_output_loss: 3.2587 - y1_output_root_mean_squared_error: 1.0806 - y2_output_root_mean_squared_error: 1.8130 - val_loss: 3.4407 - val_y1_output_loss: 1.0380 - val_y2_output_loss: 2.4096 - val_y1_output_root_mean_squared_error: 1.0235 - val_y2_output_root_mean_squared_error: 1.5470
# Epoch 72/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.8158 - y1_output_loss: 1.0649 - y2_output_loss: 2.7796 - y1_output_root_mean_squared_error: 1.0208 - y2_output_root_mean_squared_error: 1.6655 - val_loss: 5.5676 - val_y1_output_loss: 2.3030 - val_y2_output_loss: 3.4185 - val_y1_output_root_mean_squared_error: 1.5126 - val_y2_output_root_mean_squared_error: 1.8109
# Epoch 73/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.0970 - y1_output_loss: 1.3452 - y2_output_loss: 3.8846 - y1_output_root_mean_squared_error: 1.1252 - y2_output_root_mean_squared_error: 1.9573 - val_loss: 59.9532 - val_y1_output_loss: 18.4563 - val_y2_output_loss: 43.2965 - val_y1_output_root_mean_squared_error: 4.2099 - val_y2_output_root_mean_squared_error: 6.4984
# Epoch 74/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.9009 - y1_output_loss: 1.3878 - y2_output_loss: 3.5388 - y1_output_root_mean_squared_error: 1.1655 - y2_output_root_mean_squared_error: 1.8821 - val_loss: 8.2607 - val_y1_output_loss: 3.3347 - val_y2_output_loss: 5.0898 - val_y1_output_root_mean_squared_error: 1.8279 - val_y2_output_root_mean_squared_error: 2.2180
# Epoch 75/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.7736 - y1_output_loss: 1.1386 - y2_output_loss: 3.7413 - y1_output_root_mean_squared_error: 1.0488 - y2_output_root_mean_squared_error: 1.9167 - val_loss: 17.6852 - val_y1_output_loss: 7.8360 - val_y2_output_loss: 9.5112 - val_y1_output_root_mean_squared_error: 2.8325 - val_y2_output_root_mean_squared_error: 3.1084
# Epoch 76/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.7357 - y1_output_loss: 1.0823 - y2_output_loss: 2.6393 - y1_output_root_mean_squared_error: 1.0378 - y2_output_root_mean_squared_error: 1.6305 - val_loss: 2.9789 - val_y1_output_loss: 0.8174 - val_y2_output_loss: 2.1506 - val_y1_output_root_mean_squared_error: 0.9166 - val_y2_output_root_mean_squared_error: 1.4625
# Epoch 77/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.8267 - y1_output_loss: 0.8863 - y2_output_loss: 2.9153 - y1_output_root_mean_squared_error: 0.9432 - y2_output_root_mean_squared_error: 1.7138 - val_loss: 3.8767 - val_y1_output_loss: 0.7858 - val_y2_output_loss: 3.0089 - val_y1_output_root_mean_squared_error: 0.8970 - val_y2_output_root_mean_squared_error: 1.7527
# Epoch 78/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.7664 - y1_output_loss: 1.8476 - y2_output_loss: 4.9000 - y1_output_root_mean_squared_error: 1.3652 - y2_output_root_mean_squared_error: 2.2142 - val_loss: 3.5085 - val_y1_output_loss: 0.8921 - val_y2_output_loss: 2.6470 - val_y1_output_root_mean_squared_error: 0.9581 - val_y2_output_root_mean_squared_error: 1.6095
# Epoch 79/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.6590 - y1_output_loss: 0.8889 - y2_output_loss: 2.7890 - y1_output_root_mean_squared_error: 0.9459 - y2_output_root_mean_squared_error: 1.6626 - val_loss: 10.8610 - val_y1_output_loss: 2.1129 - val_y2_output_loss: 8.7461 - val_y1_output_root_mean_squared_error: 1.4506 - val_y2_output_root_mean_squared_error: 2.9592
# Epoch 80/500
# 614/614 [==============================] - 0s 130us/sample - loss: 12.3282 - y1_output_loss: 3.6480 - y2_output_loss: 8.6044 - y1_output_root_mean_squared_error: 1.9173 - y2_output_root_mean_squared_error: 2.9414 - val_loss: 3.6285 - val_y1_output_loss: 0.8575 - val_y2_output_loss: 2.7101 - val_y1_output_root_mean_squared_error: 0.9353 - val_y2_output_root_mean_squared_error: 1.6594
# Epoch 81/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.2930 - y1_output_loss: 0.7872 - y2_output_loss: 2.5400 - y1_output_root_mean_squared_error: 0.8799 - y2_output_root_mean_squared_error: 1.5870 - val_loss: 11.5279 - val_y1_output_loss: 4.9190 - val_y2_output_loss: 7.2936 - val_y1_output_root_mean_squared_error: 2.1637 - val_y2_output_root_mean_squared_error: 2.6165
# Epoch 82/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.3708 - y1_output_loss: 0.8516 - y2_output_loss: 2.4995 - y1_output_root_mean_squared_error: 0.9263 - y2_output_root_mean_squared_error: 1.5852 - val_loss: 4.6096 - val_y1_output_loss: 1.2957 - val_y2_output_loss: 3.2971 - val_y1_output_root_mean_squared_error: 1.1424 - val_y2_output_root_mean_squared_error: 1.8178
# Epoch 83/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.2606 - y1_output_loss: 0.9874 - y2_output_loss: 3.3568 - y1_output_root_mean_squared_error: 0.9854 - y2_output_root_mean_squared_error: 1.8137 - val_loss: 9.8554 - val_y1_output_loss: 3.3105 - val_y2_output_loss: 6.9846 - val_y1_output_root_mean_squared_error: 1.7673 - val_y2_output_root_mean_squared_error: 2.5946
# Epoch 84/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.6329 - y1_output_loss: 1.3251 - y2_output_loss: 4.2783 - y1_output_root_mean_squared_error: 1.1542 - y2_output_root_mean_squared_error: 2.0738 - val_loss: 4.2134 - val_y1_output_loss: 0.9757 - val_y2_output_loss: 3.1845 - val_y1_output_root_mean_squared_error: 0.9902 - val_y2_output_root_mean_squared_error: 1.7980
# Epoch 85/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.7608 - y1_output_loss: 1.6387 - y2_output_loss: 5.0852 - y1_output_root_mean_squared_error: 1.2821 - y2_output_root_mean_squared_error: 2.2621 - val_loss: 5.1787 - val_y1_output_loss: 2.0831 - val_y2_output_loss: 3.1165 - val_y1_output_root_mean_squared_error: 1.4477 - val_y2_output_root_mean_squared_error: 1.7558
# Epoch 86/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.9232 - y1_output_loss: 0.7284 - y2_output_loss: 2.2134 - y1_output_root_mean_squared_error: 0.8518 - y2_output_root_mean_squared_error: 1.4824 - val_loss: 23.6917 - val_y1_output_loss: 7.3646 - val_y2_output_loss: 17.2763 - val_y1_output_root_mean_squared_error: 2.6377 - val_y2_output_root_mean_squared_error: 4.0908
# Epoch 87/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.4173 - y1_output_loss: 0.7796 - y2_output_loss: 2.6393 - y1_output_root_mean_squared_error: 0.8831 - y2_output_root_mean_squared_error: 1.6240 - val_loss: 4.7759 - val_y1_output_loss: 0.5758 - val_y2_output_loss: 4.1280 - val_y1_output_root_mean_squared_error: 0.7667 - val_y2_output_root_mean_squared_error: 2.0465
# Epoch 88/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.2481 - y1_output_loss: 0.7370 - y2_output_loss: 2.4936 - y1_output_root_mean_squared_error: 0.8624 - y2_output_root_mean_squared_error: 1.5825 - val_loss: 2.7375 - val_y1_output_loss: 0.6431 - val_y2_output_loss: 2.1121 - val_y1_output_root_mean_squared_error: 0.8070 - val_y2_output_root_mean_squared_error: 1.4444
# Epoch 89/500
# 614/614 [==============================] - 0s 137us/sample - loss: 7.5236 - y1_output_loss: 2.0002 - y2_output_loss: 5.4802 - y1_output_root_mean_squared_error: 1.4172 - y2_output_root_mean_squared_error: 2.3484 - val_loss: 19.1108 - val_y1_output_loss: 10.3717 - val_y2_output_loss: 9.6386 - val_y1_output_root_mean_squared_error: 3.1461 - val_y2_output_root_mean_squared_error: 3.0353
# Epoch 90/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.3344 - y1_output_loss: 1.1326 - y2_output_loss: 3.1827 - y1_output_root_mean_squared_error: 1.0682 - y2_output_root_mean_squared_error: 1.7870 - val_loss: 3.6377 - val_y1_output_loss: 0.7109 - val_y2_output_loss: 2.8801 - val_y1_output_root_mean_squared_error: 0.8500 - val_y2_output_root_mean_squared_error: 1.7074
# Epoch 91/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.2014 - y1_output_loss: 0.6640 - y2_output_loss: 2.5312 - y1_output_root_mean_squared_error: 0.8121 - y2_output_root_mean_squared_error: 1.5943 - val_loss: 2.9851 - val_y1_output_loss: 0.5496 - val_y2_output_loss: 2.5182 - val_y1_output_root_mean_squared_error: 0.7519 - val_y2_output_root_mean_squared_error: 1.5555
# Epoch 92/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.1893 - y1_output_loss: 0.7261 - y2_output_loss: 2.4801 - y1_output_root_mean_squared_error: 0.8477 - y2_output_root_mean_squared_error: 1.5718 - val_loss: 2.7671 - val_y1_output_loss: 0.5957 - val_y2_output_loss: 2.1389 - val_y1_output_root_mean_squared_error: 0.7832 - val_y2_output_root_mean_squared_error: 1.4676
# Epoch 93/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.7986 - y1_output_loss: 0.5859 - y2_output_loss: 2.1875 - y1_output_root_mean_squared_error: 0.7691 - y2_output_root_mean_squared_error: 1.4856 - val_loss: 3.0207 - val_y1_output_loss: 0.6988 - val_y2_output_loss: 2.3246 - val_y1_output_root_mean_squared_error: 0.8420 - val_y2_output_root_mean_squared_error: 1.5205
# Epoch 94/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.1108 - y1_output_loss: 0.7059 - y2_output_loss: 2.4304 - y1_output_root_mean_squared_error: 0.8402 - y2_output_root_mean_squared_error: 1.5508 - val_loss: 2.6499 - val_y1_output_loss: 0.6415 - val_y2_output_loss: 2.0242 - val_y1_output_root_mean_squared_error: 0.8083 - val_y2_output_root_mean_squared_error: 1.4130
# Epoch 95/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.7000 - y1_output_loss: 0.6248 - y2_output_loss: 2.0507 - y1_output_root_mean_squared_error: 0.7942 - y2_output_root_mean_squared_error: 1.4385 - val_loss: 3.1636 - val_y1_output_loss: 0.6591 - val_y2_output_loss: 2.4541 - val_y1_output_root_mean_squared_error: 0.8168 - val_y2_output_root_mean_squared_error: 1.5800
# Epoch 96/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.3433 - y1_output_loss: 0.5762 - y2_output_loss: 1.7571 - y1_output_root_mean_squared_error: 0.7587 - y2_output_root_mean_squared_error: 1.3295 - val_loss: 2.5961 - val_y1_output_loss: 0.4508 - val_y2_output_loss: 2.1152 - val_y1_output_root_mean_squared_error: 0.6783 - val_y2_output_root_mean_squared_error: 1.4615
# Epoch 97/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.3684 - y1_output_loss: 0.4815 - y2_output_loss: 1.8968 - y1_output_root_mean_squared_error: 0.6963 - y2_output_root_mean_squared_error: 1.3724 - val_loss: 3.2156 - val_y1_output_loss: 0.6341 - val_y2_output_loss: 2.5514 - val_y1_output_root_mean_squared_error: 0.7948 - val_y2_output_root_mean_squared_error: 1.6074
# Epoch 98/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.5369 - y1_output_loss: 0.5284 - y2_output_loss: 1.9950 - y1_output_root_mean_squared_error: 0.7289 - y2_output_root_mean_squared_error: 1.4162 - val_loss: 4.4447 - val_y1_output_loss: 0.5348 - val_y2_output_loss: 3.8381 - val_y1_output_root_mean_squared_error: 0.7398 - val_y2_output_root_mean_squared_error: 1.9742
# Epoch 99/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.5876 - y1_output_loss: 0.7219 - y2_output_loss: 2.8474 - y1_output_root_mean_squared_error: 0.8497 - y2_output_root_mean_squared_error: 1.6928 - val_loss: 2.7603 - val_y1_output_loss: 0.6452 - val_y2_output_loss: 2.1068 - val_y1_output_root_mean_squared_error: 0.8095 - val_y2_output_root_mean_squared_error: 1.4509
# Epoch 100/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.9002 - y1_output_loss: 0.6078 - y2_output_loss: 2.2982 - y1_output_root_mean_squared_error: 0.7772 - y2_output_root_mean_squared_error: 1.5153 - val_loss: 2.9657 - val_y1_output_loss: 0.7575 - val_y2_output_loss: 2.2535 - val_y1_output_root_mean_squared_error: 0.8790 - val_y2_output_root_mean_squared_error: 1.4809
# Epoch 101/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.3184 - y1_output_loss: 0.5008 - y2_output_loss: 1.8193 - y1_output_root_mean_squared_error: 0.7053 - y2_output_root_mean_squared_error: 1.3494 - val_loss: 3.3740 - val_y1_output_loss: 1.1839 - val_y2_output_loss: 2.2000 - val_y1_output_root_mean_squared_error: 1.0987 - val_y2_output_root_mean_squared_error: 1.4720
# Epoch 102/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.8967 - y1_output_loss: 1.1143 - y2_output_loss: 2.7910 - y1_output_root_mean_squared_error: 1.0583 - y2_output_root_mean_squared_error: 1.6663 - val_loss: 5.4958 - val_y1_output_loss: 0.5442 - val_y2_output_loss: 4.8749 - val_y1_output_root_mean_squared_error: 0.7439 - val_y2_output_root_mean_squared_error: 2.2232
# Epoch 103/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.9918 - y1_output_loss: 0.6221 - y2_output_loss: 2.4056 - y1_output_root_mean_squared_error: 0.7910 - y2_output_root_mean_squared_error: 1.5382 - val_loss: 5.5399 - val_y1_output_loss: 0.6950 - val_y2_output_loss: 4.7288 - val_y1_output_root_mean_squared_error: 0.8415 - val_y2_output_root_mean_squared_error: 2.1981
# Epoch 104/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.6746 - y1_output_loss: 0.8345 - y2_output_loss: 2.8137 - y1_output_root_mean_squared_error: 0.9156 - y2_output_root_mean_squared_error: 1.6841 - val_loss: 2.8432 - val_y1_output_loss: 0.6608 - val_y2_output_loss: 2.1658 - val_y1_output_root_mean_squared_error: 0.8173 - val_y2_output_root_mean_squared_error: 1.4748
# Epoch 105/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.1991 - y1_output_loss: 0.5150 - y2_output_loss: 1.6681 - y1_output_root_mean_squared_error: 0.7194 - y2_output_root_mean_squared_error: 1.2968 - val_loss: 2.6015 - val_y1_output_loss: 0.7873 - val_y2_output_loss: 1.7955 - val_y1_output_root_mean_squared_error: 0.8966 - val_y2_output_root_mean_squared_error: 1.3408
# Epoch 106/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.3575 - y1_output_loss: 0.4945 - y2_output_loss: 1.8648 - y1_output_root_mean_squared_error: 0.7042 - y2_output_root_mean_squared_error: 1.3644 - val_loss: 5.0096 - val_y1_output_loss: 0.8946 - val_y2_output_loss: 4.3626 - val_y1_output_root_mean_squared_error: 0.9343 - val_y2_output_root_mean_squared_error: 2.0339
# Epoch 107/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.8640 - y1_output_loss: 0.6157 - y2_output_loss: 2.2336 - y1_output_root_mean_squared_error: 0.7869 - y2_output_root_mean_squared_error: 1.4983 - val_loss: 4.0004 - val_y1_output_loss: 0.5369 - val_y2_output_loss: 3.3736 - val_y1_output_root_mean_squared_error: 0.7377 - val_y2_output_root_mean_squared_error: 1.8591
# Epoch 108/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.0764 - y1_output_loss: 0.5053 - y2_output_loss: 1.6388 - y1_output_root_mean_squared_error: 0.7137 - y2_output_root_mean_squared_error: 1.2518 - val_loss: 7.2511 - val_y1_output_loss: 1.1620 - val_y2_output_loss: 6.3566 - val_y1_output_root_mean_squared_error: 1.0795 - val_y2_output_root_mean_squared_error: 2.4669
# Epoch 109/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.5557 - y1_output_loss: 0.8353 - y2_output_loss: 2.7005 - y1_output_root_mean_squared_error: 0.9164 - y2_output_root_mean_squared_error: 1.6480 - val_loss: 3.7352 - val_y1_output_loss: 0.9953 - val_y2_output_loss: 2.6983 - val_y1_output_root_mean_squared_error: 1.0003 - val_y2_output_root_mean_squared_error: 1.6537
# Epoch 110/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.8399 - y1_output_loss: 0.7311 - y2_output_loss: 2.0827 - y1_output_root_mean_squared_error: 0.8590 - y2_output_root_mean_squared_error: 1.4498 - val_loss: 2.6161 - val_y1_output_loss: 0.6387 - val_y2_output_loss: 2.0282 - val_y1_output_root_mean_squared_error: 0.8042 - val_y2_output_root_mean_squared_error: 1.4033
# Epoch 111/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.6666 - y1_output_loss: 0.8628 - y2_output_loss: 2.7871 - y1_output_root_mean_squared_error: 0.9316 - y2_output_root_mean_squared_error: 1.6730 - val_loss: 3.5035 - val_y1_output_loss: 1.0233 - val_y2_output_loss: 2.5841 - val_y1_output_root_mean_squared_error: 1.0080 - val_y2_output_root_mean_squared_error: 1.5772
# Epoch 112/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.3167 - y1_output_loss: 0.5634 - y2_output_loss: 1.7374 - y1_output_root_mean_squared_error: 0.7538 - y2_output_root_mean_squared_error: 1.3223 - val_loss: 2.4154 - val_y1_output_loss: 0.6377 - val_y2_output_loss: 1.7590 - val_y1_output_root_mean_squared_error: 0.8085 - val_y2_output_root_mean_squared_error: 1.3273
# Epoch 113/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.7985 - y1_output_loss: 0.5478 - y2_output_loss: 2.2285 - y1_output_root_mean_squared_error: 0.7427 - y2_output_root_mean_squared_error: 1.4990 - val_loss: 1.9763 - val_y1_output_loss: 0.5466 - val_y2_output_loss: 1.4255 - val_y1_output_root_mean_squared_error: 0.7446 - val_y2_output_root_mean_squared_error: 1.1924
# Epoch 114/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.5399 - y1_output_loss: 0.5585 - y2_output_loss: 1.9830 - y1_output_root_mean_squared_error: 0.7459 - y2_output_root_mean_squared_error: 1.4084 - val_loss: 4.7777 - val_y1_output_loss: 1.7525 - val_y2_output_loss: 3.0473 - val_y1_output_root_mean_squared_error: 1.3383 - val_y2_output_root_mean_squared_error: 1.7282
# Epoch 115/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.6172 - y1_output_loss: 0.5734 - y2_output_loss: 2.0510 - y1_output_root_mean_squared_error: 0.7527 - y2_output_root_mean_squared_error: 1.4320 - val_loss: 6.0174 - val_y1_output_loss: 2.3569 - val_y2_output_loss: 3.7748 - val_y1_output_root_mean_squared_error: 1.5086 - val_y2_output_root_mean_squared_error: 1.9343
# Epoch 116/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.0021 - y1_output_loss: 0.4875 - y2_output_loss: 1.5155 - y1_output_root_mean_squared_error: 0.6948 - y2_output_root_mean_squared_error: 1.2326 - val_loss: 2.2598 - val_y1_output_loss: 0.5265 - val_y2_output_loss: 1.7180 - val_y1_output_root_mean_squared_error: 0.7311 - val_y2_output_root_mean_squared_error: 1.3135
# Epoch 117/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.1526 - y1_output_loss: 0.4858 - y2_output_loss: 1.6505 - y1_output_root_mean_squared_error: 0.6994 - y2_output_root_mean_squared_error: 1.2897 - val_loss: 2.3659 - val_y1_output_loss: 0.5518 - val_y2_output_loss: 1.7916 - val_y1_output_root_mean_squared_error: 0.7467 - val_y2_output_root_mean_squared_error: 1.3447
# Epoch 118/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.1623 - y1_output_loss: 0.8817 - y2_output_loss: 2.2619 - y1_output_root_mean_squared_error: 0.9395 - y2_output_root_mean_squared_error: 1.5099 - val_loss: 2.7767 - val_y1_output_loss: 0.8040 - val_y2_output_loss: 1.9594 - val_y1_output_root_mean_squared_error: 0.8998 - val_y2_output_root_mean_squared_error: 1.4025
# Epoch 119/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.5176 - y1_output_loss: 0.6297 - y2_output_loss: 1.9096 - y1_output_root_mean_squared_error: 0.7862 - y2_output_root_mean_squared_error: 1.3782 - val_loss: 9.2698 - val_y1_output_loss: 2.2377 - val_y2_output_loss: 7.1539 - val_y1_output_root_mean_squared_error: 1.4751 - val_y2_output_root_mean_squared_error: 2.6635
# Epoch 120/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.4762 - y1_output_loss: 0.6208 - y2_output_loss: 1.8513 - y1_output_root_mean_squared_error: 0.7904 - y2_output_root_mean_squared_error: 1.3607 - val_loss: 3.5144 - val_y1_output_loss: 0.7908 - val_y2_output_loss: 2.7081 - val_y1_output_root_mean_squared_error: 0.8866 - val_y2_output_root_mean_squared_error: 1.6518
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3835 - y1_output_loss: 0.1276 - y2_output_loss: 0.2544 - y1_output_root_mean_squared_error: 0.3576 - y2_output_root_mean_squared_error: 0.5056 - val_loss: 1.1943 - val_y1_output_loss: 0.2984 - val_y2_output_loss: 0.8879 - val_y1_output_root_mean_squared_error: 0.5561 - val_y2_output_root_mean_squared_error: 0.9408
# Epoch 462/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4086 - y1_output_loss: 0.1346 - y2_output_loss: 0.2716 - y1_output_root_mean_squared_error: 0.3678 - y2_output_root_mean_squared_error: 0.5228 - val_loss: 1.0250 - val_y1_output_loss: 0.2272 - val_y2_output_loss: 0.7885 - val_y1_output_root_mean_squared_error: 0.4789 - val_y2_output_root_mean_squared_error: 0.8920
# Epoch 463/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4613 - y1_output_loss: 0.1369 - y2_output_loss: 0.3222 - y1_output_root_mean_squared_error: 0.3703 - y2_output_root_mean_squared_error: 0.5694 - val_loss: 1.0542 - val_y1_output_loss: 0.3109 - val_y2_output_loss: 0.7802 - val_y1_output_root_mean_squared_error: 0.5387 - val_y2_output_root_mean_squared_error: 0.8741
# Epoch 464/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.5087 - y1_output_loss: 0.1660 - y2_output_loss: 0.3428 - y1_output_root_mean_squared_error: 0.4061 - y2_output_root_mean_squared_error: 0.5864 - val_loss: 1.0004 - val_y1_output_loss: 0.2680 - val_y2_output_loss: 0.7569 - val_y1_output_root_mean_squared_error: 0.5118 - val_y2_output_root_mean_squared_error: 0.8594
# Epoch 465/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4259 - y1_output_loss: 0.1257 - y2_output_loss: 0.2968 - y1_output_root_mean_squared_error: 0.3561 - y2_output_root_mean_squared_error: 0.5469 - val_loss: 0.9981 - val_y1_output_loss: 0.2282 - val_y2_output_loss: 0.7641 - val_y1_output_root_mean_squared_error: 0.4781 - val_y2_output_root_mean_squared_error: 0.8773
# Epoch 466/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3171 - y1_output_loss: 0.1039 - y2_output_loss: 0.2134 - y1_output_root_mean_squared_error: 0.3198 - y2_output_root_mean_squared_error: 0.4635 - val_loss: 1.2399 - val_y1_output_loss: 0.3449 - val_y2_output_loss: 0.8647 - val_y1_output_root_mean_squared_error: 0.5983 - val_y2_output_root_mean_squared_error: 0.9391
# Epoch 467/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3876 - y1_output_loss: 0.1263 - y2_output_loss: 0.2656 - y1_output_root_mean_squared_error: 0.3503 - y2_output_root_mean_squared_error: 0.5147 - val_loss: 1.5043 - val_y1_output_loss: 0.3211 - val_y2_output_loss: 1.1706 - val_y1_output_root_mean_squared_error: 0.5444 - val_y2_output_root_mean_squared_error: 1.0991
# Epoch 468/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3641 - y1_output_loss: 0.1072 - y2_output_loss: 0.2580 - y1_output_root_mean_squared_error: 0.3277 - y2_output_root_mean_squared_error: 0.5067 - val_loss: 1.0781 - val_y1_output_loss: 0.2823 - val_y2_output_loss: 0.8407 - val_y1_output_root_mean_squared_error: 0.5207 - val_y2_output_root_mean_squared_error: 0.8983
# Epoch 469/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4631 - y1_output_loss: 0.1298 - y2_output_loss: 0.3359 - y1_output_root_mean_squared_error: 0.3593 - y2_output_root_mean_squared_error: 0.5779 - val_loss: 1.0963 - val_y1_output_loss: 0.2431 - val_y2_output_loss: 0.9051 - val_y1_output_root_mean_squared_error: 0.4885 - val_y2_output_root_mean_squared_error: 0.9261
# Epoch 470/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3924 - y1_output_loss: 0.1195 - y2_output_loss: 0.2714 - y1_output_root_mean_squared_error: 0.3458 - y2_output_root_mean_squared_error: 0.5223 - val_loss: 1.0303 - val_y1_output_loss: 0.2597 - val_y2_output_loss: 0.7852 - val_y1_output_root_mean_squared_error: 0.5052 - val_y2_output_root_mean_squared_error: 0.8804
# Epoch 471/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3554 - y1_output_loss: 0.1180 - y2_output_loss: 0.2383 - y1_output_root_mean_squared_error: 0.3445 - y2_output_root_mean_squared_error: 0.4866 - val_loss: 1.5487 - val_y1_output_loss: 0.3112 - val_y2_output_loss: 1.1995 - val_y1_output_root_mean_squared_error: 0.5672 - val_y2_output_root_mean_squared_error: 1.1077
# Epoch 472/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4817 - y1_output_loss: 0.1380 - y2_output_loss: 0.3427 - y1_output_root_mean_squared_error: 0.3725 - y2_output_root_mean_squared_error: 0.5856 - val_loss: 1.3404 - val_y1_output_loss: 0.2435 - val_y2_output_loss: 1.0648 - val_y1_output_root_mean_squared_error: 0.4983 - val_y2_output_root_mean_squared_error: 1.0450
# Epoch 473/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3361 - y1_output_loss: 0.1245 - y2_output_loss: 0.2237 - y1_output_root_mean_squared_error: 0.3345 - y2_output_root_mean_squared_error: 0.4735 - val_loss: 1.3457 - val_y1_output_loss: 0.3348 - val_y2_output_loss: 0.9831 - val_y1_output_root_mean_squared_error: 0.5805 - val_y2_output_root_mean_squared_error: 1.0044
# Epoch 474/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3717 - y1_output_loss: 0.1141 - y2_output_loss: 0.2597 - y1_output_root_mean_squared_error: 0.3394 - y2_output_root_mean_squared_error: 0.5064 - val_loss: 1.2084 - val_y1_output_loss: 0.2270 - val_y2_output_loss: 1.0653 - val_y1_output_root_mean_squared_error: 0.4678 - val_y2_output_root_mean_squared_error: 0.9948
# Epoch 475/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3431 - y1_output_loss: 0.1104 - y2_output_loss: 0.2355 - y1_output_root_mean_squared_error: 0.3320 - y2_output_root_mean_squared_error: 0.4826 - val_loss: 1.2793 - val_y1_output_loss: 0.2301 - val_y2_output_loss: 1.1134 - val_y1_output_root_mean_squared_error: 0.4743 - val_y2_output_root_mean_squared_error: 1.0268
# Epoch 476/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3330 - y1_output_loss: 0.1097 - y2_output_loss: 0.2229 - y1_output_root_mean_squared_error: 0.3318 - y2_output_root_mean_squared_error: 0.4721 - val_loss: 1.2413 - val_y1_output_loss: 0.2313 - val_y2_output_loss: 0.9789 - val_y1_output_root_mean_squared_error: 0.4856 - val_y2_output_root_mean_squared_error: 1.0028
# Epoch 477/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3205 - y1_output_loss: 0.1174 - y2_output_loss: 0.2045 - y1_output_root_mean_squared_error: 0.3428 - y2_output_root_mean_squared_error: 0.4505 - val_loss: 1.0523 - val_y1_output_loss: 0.1974 - val_y2_output_loss: 0.8946 - val_y1_output_root_mean_squared_error: 0.4368 - val_y2_output_root_mean_squared_error: 0.9282
# Epoch 478/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4369 - y1_output_loss: 0.1305 - y2_output_loss: 0.3046 - y1_output_root_mean_squared_error: 0.3611 - y2_output_root_mean_squared_error: 0.5537 - val_loss: 1.0125 - val_y1_output_loss: 0.2889 - val_y2_output_loss: 0.7381 - val_y1_output_root_mean_squared_error: 0.5355 - val_y2_output_root_mean_squared_error: 0.8519
# Epoch 479/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3428 - y1_output_loss: 0.1009 - y2_output_loss: 0.2483 - y1_output_root_mean_squared_error: 0.3158 - y2_output_root_mean_squared_error: 0.4931 - val_loss: 2.0228 - val_y1_output_loss: 0.3033 - val_y2_output_loss: 1.6600 - val_y1_output_root_mean_squared_error: 0.5581 - val_y2_output_root_mean_squared_error: 1.3082
# Epoch 480/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3664 - y1_output_loss: 0.1171 - y2_output_loss: 0.2463 - y1_output_root_mean_squared_error: 0.3435 - y2_output_root_mean_squared_error: 0.4984 - val_loss: 0.9678 - val_y1_output_loss: 0.2061 - val_y2_output_loss: 0.7846 - val_y1_output_root_mean_squared_error: 0.4499 - val_y2_output_root_mean_squared_error: 0.8749
# Epoch 481/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3380 - y1_output_loss: 0.1116 - y2_output_loss: 0.2256 - y1_output_root_mean_squared_error: 0.3341 - y2_output_root_mean_squared_error: 0.4758 - val_loss: 1.0518 - val_y1_output_loss: 0.2667 - val_y2_output_loss: 0.7801 - val_y1_output_root_mean_squared_error: 0.5148 - val_y2_output_root_mean_squared_error: 0.8870
# Epoch 482/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4425 - y1_output_loss: 0.1181 - y2_output_loss: 0.3215 - y1_output_root_mean_squared_error: 0.3433 - y2_output_root_mean_squared_error: 0.5698 - val_loss: 1.0134 - val_y1_output_loss: 0.2430 - val_y2_output_loss: 0.7812 - val_y1_output_root_mean_squared_error: 0.4931 - val_y2_output_root_mean_squared_error: 0.8776
# Epoch 483/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4017 - y1_output_loss: 0.1180 - y2_output_loss: 0.2839 - y1_output_root_mean_squared_error: 0.3444 - y2_output_root_mean_squared_error: 0.5320 - val_loss: 1.2187 - val_y1_output_loss: 0.2243 - val_y2_output_loss: 0.9640 - val_y1_output_root_mean_squared_error: 0.4785 - val_y2_output_root_mean_squared_error: 0.9949
# Epoch 484/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3400 - y1_output_loss: 0.1215 - y2_output_loss: 0.2181 - y1_output_root_mean_squared_error: 0.3498 - y2_output_root_mean_squared_error: 0.4665 - val_loss: 1.1015 - val_y1_output_loss: 0.2457 - val_y2_output_loss: 0.8862 - val_y1_output_root_mean_squared_error: 0.4918 - val_y2_output_root_mean_squared_error: 0.9272
# Epoch 485/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3980 - y1_output_loss: 0.1171 - y2_output_loss: 0.2788 - y1_output_root_mean_squared_error: 0.3434 - y2_output_root_mean_squared_error: 0.5292 - val_loss: 0.9709 - val_y1_output_loss: 0.2217 - val_y2_output_loss: 0.7576 - val_y1_output_root_mean_squared_error: 0.4699 - val_y2_output_root_mean_squared_error: 0.8661
# Epoch 486/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3236 - y1_output_loss: 0.1074 - y2_output_loss: 0.2140 - y1_output_root_mean_squared_error: 0.3290 - y2_output_root_mean_squared_error: 0.4640 - val_loss: 1.0161 - val_y1_output_loss: 0.2461 - val_y2_output_loss: 0.7610 - val_y1_output_root_mean_squared_error: 0.5007 - val_y2_output_root_mean_squared_error: 0.8749
# Epoch 487/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3422 - y1_output_loss: 0.1061 - y2_output_loss: 0.2332 - y1_output_root_mean_squared_error: 0.3271 - y2_output_root_mean_squared_error: 0.4851 - val_loss: 0.9502 - val_y1_output_loss: 0.2066 - val_y2_output_loss: 0.7497 - val_y1_output_root_mean_squared_error: 0.4577 - val_y2_output_root_mean_squared_error: 0.8607
# Epoch 488/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.5604 - y1_output_loss: 0.1545 - y2_output_loss: 0.4187 - y1_output_root_mean_squared_error: 0.3906 - y2_output_root_mean_squared_error: 0.6386 - val_loss: 3.0009 - val_y1_output_loss: 0.3632 - val_y2_output_loss: 2.5708 - val_y1_output_root_mean_squared_error: 0.6080 - val_y2_output_root_mean_squared_error: 1.6221
# Epoch 489/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4787 - y1_output_loss: 0.1212 - y2_output_loss: 0.3614 - y1_output_root_mean_squared_error: 0.3485 - y2_output_root_mean_squared_error: 0.5978 - val_loss: 2.2945 - val_y1_output_loss: 0.4294 - val_y2_output_loss: 1.8134 - val_y1_output_root_mean_squared_error: 0.6667 - val_y2_output_root_mean_squared_error: 1.3602
# Epoch 490/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.5622 - y1_output_loss: 0.1396 - y2_output_loss: 0.4189 - y1_output_root_mean_squared_error: 0.3742 - y2_output_root_mean_squared_error: 0.6498 - val_loss: 0.9457 - val_y1_output_loss: 0.2068 - val_y2_output_loss: 0.7548 - val_y1_output_root_mean_squared_error: 0.4536 - val_y2_output_root_mean_squared_error: 0.8602
# Epoch 491/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4388 - y1_output_loss: 0.1201 - y2_output_loss: 0.3154 - y1_output_root_mean_squared_error: 0.3473 - y2_output_root_mean_squared_error: 0.5641 - val_loss: 1.0760 - val_y1_output_loss: 0.2552 - val_y2_output_loss: 0.8127 - val_y1_output_root_mean_squared_error: 0.5070 - val_y2_output_root_mean_squared_error: 0.9049
# Epoch 492/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3913 - y1_output_loss: 0.1123 - y2_output_loss: 0.2825 - y1_output_root_mean_squared_error: 0.3334 - y2_output_root_mean_squared_error: 0.5293 - val_loss: 1.6377 - val_y1_output_loss: 0.2453 - val_y2_output_loss: 1.4952 - val_y1_output_root_mean_squared_error: 0.4881 - val_y2_output_root_mean_squared_error: 1.1830
# Epoch 493/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.5998 - y1_output_loss: 0.1610 - y2_output_loss: 0.4357 - y1_output_root_mean_squared_error: 0.4017 - y2_output_root_mean_squared_error: 0.6621 - val_loss: 1.0018 - val_y1_output_loss: 0.2354 - val_y2_output_loss: 0.7564 - val_y1_output_root_mean_squared_error: 0.4876 - val_y2_output_root_mean_squared_error: 0.8741
# Epoch 494/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4326 - y1_output_loss: 0.1427 - y2_output_loss: 0.2861 - y1_output_root_mean_squared_error: 0.3795 - y2_output_root_mean_squared_error: 0.5372 - val_loss: 0.9074 - val_y1_output_loss: 0.2001 - val_y2_output_loss: 0.7089 - val_y1_output_root_mean_squared_error: 0.4443 - val_y2_output_root_mean_squared_error: 0.8426
# Epoch 495/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4059 - y1_output_loss: 0.1221 - y2_output_loss: 0.2816 - y1_output_root_mean_squared_error: 0.3507 - y2_output_root_mean_squared_error: 0.5320 - val_loss: 0.9722 - val_y1_output_loss: 0.2162 - val_y2_output_loss: 0.7560 - val_y1_output_root_mean_squared_error: 0.4684 - val_y2_output_root_mean_squared_error: 0.8677
# Epoch 496/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3643 - y1_output_loss: 0.1097 - y2_output_loss: 0.2520 - y1_output_root_mean_squared_error: 0.3325 - y2_output_root_mean_squared_error: 0.5037 - val_loss: 0.9377 - val_y1_output_loss: 0.2200 - val_y2_output_loss: 0.7306 - val_y1_output_root_mean_squared_error: 0.4709 - val_y2_output_root_mean_squared_error: 0.8461
# Epoch 497/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3640 - y1_output_loss: 0.1063 - y2_output_loss: 0.2557 - y1_output_root_mean_squared_error: 0.3269 - y2_output_root_mean_squared_error: 0.5071 - val_loss: 1.0929 - val_y1_output_loss: 0.2317 - val_y2_output_loss: 0.8540 - val_y1_output_root_mean_squared_error: 0.4848 - val_y2_output_root_mean_squared_error: 0.9262
# Epoch 498/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3023 - y1_output_loss: 0.1037 - y2_output_loss: 0.2000 - y1_output_root_mean_squared_error: 0.3202 - y2_output_root_mean_squared_error: 0.4469 - val_loss: 1.2976 - val_y1_output_loss: 0.4800 - val_y2_output_loss: 0.8630 - val_y1_output_root_mean_squared_error: 0.6622 - val_y2_output_root_mean_squared_error: 0.9269
# Epoch 499/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.2926 - y1_output_loss: 0.1129 - y2_output_loss: 0.1799 - y1_output_root_mean_squared_error: 0.3358 - y2_output_root_mean_squared_error: 0.4241 - val_loss: 0.9433 - val_y1_output_loss: 0.2400 - val_y2_output_loss: 0.7092 - val_y1_output_root_mean_squared_error: 0.4866 - val_y2_output_root_mean_squared_error: 0.8406
# Epoch 500/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4702 - y1_output_loss: 0.1286 - y2_output_loss: 0.3387 - y1_output_root_mean_squared_error: 0.3600 - y2_output_root_mean_squared_error: 0.5836 - val_loss: 0.9875 - val_y1_output_loss: 0.2211 - val_y2_output_loss: 0.7854 - val_y1_output_root_mean_squared_error: 0.4652 - val_y2_output_root_mean_squared_error: 0.8781

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 34us/sample - loss: 0.9875 - y1_output_loss: 0.2250 - y2_output_loss: 0.7582 - y1_output_root_mean_squared_error: 0.4652 - y2_output_root_mean_squared_error: 0.8781
# Loss = 0.9875151104741282, Y1_loss = 0.22498533129692078, Y1_mse = 0.46524280309677124, Y2_loss = 0.7582038640975952, Y2_mse = 0.8781026601791382

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
